# %%
# !pip install modin[ray]
# Out:
# Requirement already satisfied: modin[ray] in d:\anaconda\lib\site-packages (0.15.2)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from modin[ray]) (5.8.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from modin[ray]) (21.3)
# Requirement already satisfied: pandas==1.4.3 in d:\anaconda\lib\site-packages (from modin[ray]) (1.4.3)
# Requirement already satisfied: fsspec in d:\anaconda\lib\site-packages (from modin[ray]) (2022.2.0)
# Requirement already satisfied: numpy>=1.18.5 in d:\anaconda\lib\site-packages (from modin[ray]) (1.21.5)
# Requirement already satisfied: ray[default]<1.13.0,>=1.4.0 in d:\anaconda\lib\site-packages (from modin[ray]) (1.12.1)
# Requirement already satisfied: redis<4.0.0,>=3.5.0 in d:\anaconda\lib\site-packages (from modin[ray]) (3.5.3)
# Requirement already satisfied: protobuf<4.0.0 in d:\anaconda\lib\site-packages (from modin[ray]) (3.19.1)
# Requirement already satisfied: pyarrow>=4.0.1 in d:\anaconda\lib\site-packages (from modin[ray]) (8.0.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas==1.4.3->modin[ray]) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas==1.4.3->modin[ray]) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.4.3->modin[ray]) (1.16.0)
# Requirement already satisfied: virtualenv in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (20.15.0)
# Requirement already satisfied: click>=7.0 in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (8.0.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.0.2)
# Requirement already satisfied: aiosignal in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.2.0)
# Requirement already satisfied: jsonschema in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.4.0)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.42.0)
# Requirement already satisfied: frozenlist in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.2.0)
# Requirement already satisfied: attrs in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (21.4.0)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (3.6.0)
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (6.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.27.1)
# Requirement already satisfied: gpustat>=1.0.0b1 in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.0.0b1)
# Requirement already satisfied: aiohttp>=3.7 in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (3.8.1)
# Requirement already satisfied: prometheus-client<0.14.0,>=0.7.1 in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.13.1)
# Requirement already satisfied: smart-open in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (5.1.0)
# Requirement already satisfied: aiohttp-cors in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.7.0)
# Requirement already satisfied: colorful in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.5.4)
# Requirement already satisfied: py-spy>=0.2.0 in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.3.12)
# Requirement already satisfied: opencensus in d:\anaconda\lib\site-packages (from ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.9.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in d:\anaconda\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (5.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda\lib\site-packages (from aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in d:\anaconda\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.1.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=7.0->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.4.4)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in d:\anaconda\lib\site-packages (from gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (7.352.0)
# Requirement already satisfied: blessed>=1.17.1 in d:\anaconda\lib\site-packages (from gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.19.1)
# Requirement already satisfied: jinxed>=1.1.0 in d:\anaconda\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.2.0)
# Requirement already satisfied: wcwidth>=0.1.4 in d:\anaconda\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.2.5)
# Requirement already satisfied: ansicon in d:\anaconda\lib\site-packages (from jinxed>=1.1.0->blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.89.0)
# Requirement already satisfied: idna>=2.0 in d:\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp>=3.7->ray[default]<1.13.0,>=1.4.0->modin[ray]) (3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.18.0)
# Requirement already satisfied: opencensus-context>=0.1.2 in d:\anaconda\lib\site-packages (from opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.1.2)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in d:\anaconda\lib\site-packages (from opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.25.1)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in d:\anaconda\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.33.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in d:\anaconda\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.53.0)
# Requirement already satisfied: setuptools>=40.3.0 in d:\anaconda\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (61.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->ray[default]<1.13.0,>=1.4.0->modin[ray]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2021.10.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\lib\site-packages (from packaging->modin[ray]) (3.0.4)
# Requirement already satisfied: platformdirs<3,>=2 in d:\anaconda\lib\site-packages (from virtualenv->ray[default]<1.13.0,>=1.4.0->modin[ray]) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.1 in d:\anaconda\lib\site-packages (from virtualenv->ray[default]<1.13.0,>=1.4.0->modin[ray]) (0.3.4)

# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv('test2.csv')
df
# Out:
# CPU times: total: 14.6 s
# Wall time: 17.8 s
#                             file  round    tick    seconds att_team vic_team  \
# 0        esea_match_13818366.dem      1   21257   165.8779   Team 2   Team 1
# 1        esea_match_13818366.dem      1   21653   168.9752   Team 1   Team 2
# 2        esea_match_13818366.dem      1   21717   169.4758   Team 1   Team 2
# 3        esea_match_13818366.dem      1   21937   171.1965   Team 1   Team 2
# 4        esea_match_13818366.dem      1   22229   173.4804   Team 1   Team 2
# ...                          ...    ...     ...        ...      ...      ...
# 4546080  esea_match_13829173.dem     22  243361  1901.4210   Team 1   Team 2
# 4546081  esea_match_13829173.dem     22  243373  1901.5150   Team 1   Team 2
# 4546082  esea_match_13829173.dem     22  243405  1901.7650   Team 2   Team 1
# 4546083  esea_match_13829173.dem     22  243719  1904.2230   Team 2   Team 1
# 4546084  esea_match_13829173.dem     22  243755  1904.5050   Team 1   Team 2
#
#                  att_side          vic_side  hp_dmg  arm_dmg  ...     wp  \
# 0               Terrorist  CounterTerrorist      20        0  ...  Glock
# 1        CounterTerrorist         Terrorist     100        0  ...    USP
# 2        CounterTerrorist         Terrorist     100        0  ...    USP
# 3        CounterTerrorist         Terrorist      14        6  ...    USP
# 4        CounterTerrorist         Terrorist     100        0  ...    USP
# ...                   ...               ...     ...      ...  ...    ...
# 4546080         Terrorist  CounterTerrorist      20        2  ...   AK47
# 4546081         Terrorist  CounterTerrorist      26        3  ...   AK47
# 4546082  CounterTerrorist         Terrorist     100       15  ...   AK47
# 4546083  CounterTerrorist         Terrorist      27        4  ...   AK47
# 4546084         Terrorist  CounterTerrorist      54       16  ...   AK47
#
#         wp_type             att_id att_rank             vic_id  vic_rank  \
# 0        Pistol  76561198242409332        0  76561198323654039         0
# 1        Pistol  76561198013283167        0  76561198355844440         0
# 2        Pistol  76561198323654039        0  76561198305399476         0
# 3        Pistol  76561198323654039        0  76561197962070685         0
# 4        Pistol  76561198853893462        0  76561198397252030         0
# ...         ...                ...      ...                ...       ...
# 4546080   Rifle  76561197986109746        0  76561198047370175         0
# 4546081   Rifle  76561197986109746        0  76561198047370175         0
# 4546082   Rifle  76561198047370175        0  76561197986109746         0
# 4546083   Rifle  76561198047370175        0  76561198103856560         0
# 4546084   Rifle  76561198103856560        0  76561198047370175         0
#
#          att_pos_x  att_pos_y  vic_pos_x  vic_pos_y
# 0         695.9623  1459.5790  -299.9824  2220.1480
# 1        -236.3433   923.7209   271.5201  2097.4790
# 2        -422.4744  2051.0920   909.0534  1543.7200
# 3        -263.6333  2248.5440   704.7518  1579.3470
# 4        -558.0109  -874.1711   254.4920  -691.1022
# ...            ...        ...        ...        ...
# 4546080 -1132.0250  -191.1473 -1220.2790 -1279.4920
# 4546081 -1132.0250  -191.1473 -1218.2490 -1275.2540
# 4546082 -1205.9710 -1271.5040 -1132.0250  -191.1473
# 4546083 -1217.5950 -1091.5430 -1373.8790  -931.7026
# 4546084 -1378.4040  -936.3403 -1215.1200 -1089.2760
#
# [4546085 rows x 23 columns]

# %%
import modin.pandas as pd

# %%
# %%time
df = pd.read_csv('test2.csv')
df
# Out:
# CPU times: total: 1.03 s
# Wall time: 8.75 s
#                             file  round    tick    seconds att_team vic_team  \
# 0        esea_match_13818366.dem      1   21257   165.8779   Team 2   Team 1
# 1        esea_match_13818366.dem      1   21653   168.9752   Team 1   Team 2
# 2        esea_match_13818366.dem      1   21717   169.4758   Team 1   Team 2
# 3        esea_match_13818366.dem      1   21937   171.1965   Team 1   Team 2
# 4        esea_match_13818366.dem      1   22229   173.4804   Team 1   Team 2
# ...                          ...    ...     ...        ...      ...      ...
# 4546080  esea_match_13829173.dem     22  243361  1901.4210   Team 1   Team 2
# 4546081  esea_match_13829173.dem     22  243373  1901.5150   Team 1   Team 2
# 4546082  esea_match_13829173.dem     22  243405  1901.7650   Team 2   Team 1
# 4546083  esea_match_13829173.dem     22  243719  1904.2230   Team 2   Team 1
# 4546084  esea_match_13829173.dem     22  243755  1904.5050   Team 1   Team 2
#
#                  att_side          vic_side  hp_dmg  arm_dmg  ...     wp  \
# 0               Terrorist  CounterTerrorist      20        0  ...  Glock
# 1        CounterTerrorist         Terrorist     100        0  ...    USP
# 2        CounterTerrorist         Terrorist     100        0  ...    USP
# 3        CounterTerrorist         Terrorist      14        6  ...    USP
# 4        CounterTerrorist         Terrorist     100        0  ...    USP
# ...                   ...               ...     ...      ...  ...    ...
# 4546080         Terrorist  CounterTerrorist      20        2  ...   AK47
# 4546081         Terrorist  CounterTerrorist      26        3  ...   AK47
# 4546082  CounterTerrorist         Terrorist     100       15  ...   AK47
# 4546083  CounterTerrorist         Terrorist      27        4  ...   AK47
# 4546084         Terrorist  CounterTerrorist      54       16  ...   AK47
#
#         wp_type             att_id att_rank             vic_id  vic_rank  \
# 0        Pistol  76561198242409332        0  76561198323654039         0
# 1        Pistol  76561198013283167        0  76561198355844440         0
# 2        Pistol  76561198323654039        0  76561198305399476         0
# 3        Pistol  76561198323654039        0  76561197962070685         0
# 4        Pistol  76561198853893462        0  76561198397252030         0
# ...         ...                ...      ...                ...       ...
# 4546080   Rifle  76561197986109746        0  76561198047370175         0
# 4546081   Rifle  76561197986109746        0  76561198047370175         0
# 4546082   Rifle  76561198047370175        0  76561197986109746         0
# 4546083   Rifle  76561198047370175        0  76561198103856560         0
# 4546084   Rifle  76561198103856560        0  76561198047370175         0
#
#          att_pos_x  att_pos_y  vic_pos_x  vic_pos_y
# 0         695.9623  1459.5790  -299.9824  2220.1480
# 1        -236.3433   923.7209   271.5201  2097.4790
# 2        -422.4744  2051.0920   909.0534  1543.7200
# 3        -263.6333  2248.5440   704.7518  1579.3470
# 4        -558.0109  -874.1711   254.4920  -691.1022
# ...            ...        ...        ...        ...
# 4546080 -1132.0250  -191.1473 -1220.2790 -1279.4920
# 4546081 -1132.0250  -191.1473 -1218.2490 -1275.2540
# 4546082 -1205.9710 -1271.5040 -1132.0250  -191.1473
# 4546083 -1217.5950 -1091.5430 -1373.8790  -931.7026
# 4546084 -1378.4040  -936.3403 -1215.1200 -1089.2760
#
# [4546085 rows x 23 columns]

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: total: 328 ms
# Wall time: 4.21 s
#                          file    round     tick  seconds  vic_team  att_side  \
# att_team
# --to be determined--      647      647      647      647       647       647
# ALTERNATE aTTaX           791      791      791      791       791       791
# BOOT-dS Letou             610      610      610      610       610       610
# Cerus eSports             338      338      338      338       338       338
# Chiefs                    823      823      823      823       823       823
# Dynasty                   710      710      710      710       710       710
# FlashGaming               660      660      660      660       660       660
# Grayhound                 759      759      759      759       759       759
# Ground Zero               720      720      720      720       720       720
# Guerrilla Tactics         350      350      350      350       350       350
# Legacy                    316      316      316      316       316       316
# MVP PK                   1151     1151     1151     1151      1151      1151
# PRiDE                     399      399      399      399       399       399
# SYF                       735      735      735      735       735       735
# SZ Absolute              1145     1145     1145     1145      1145      1145
# Taboo                     596      596      596      596       596       596
# Team 1                2290388  2290388  2290388  2290127   2290388   2290388
# Team 2                2200193  2200193  2200193  2199820   2200193   2200193
# World                   44184    44184    44184    44180     44184     44184
# anime savants             204      204      204      204       204       204
# x-kom Team                366      366      366      366       366       366
#
#                       vic_side   hp_dmg  arm_dmg  is_bomb_planted  ...  \
# att_team                                                           ...
# --to be determined--       647      647      647              647  ...
# ALTERNATE aTTaX            791      791      791              791  ...
# BOOT-dS Letou              610      610      610              610  ...
# Cerus eSports              338      338      338              338  ...
# Chiefs                     823      823      823              823  ...
# Dynasty                    710      710      710              710  ...
# FlashGaming                660      660      660              660  ...
# Grayhound                  759      759      759              759  ...
# Ground Zero                720      720      720              720  ...
# Guerrilla Tactics          350      350      350              350  ...
# Legacy                     316      316      316              316  ...
# MVP PK                    1151     1151     1151             1151  ...
# PRiDE                      399      399      399              399  ...
# SYF                        735      735      735              735  ...
# SZ Absolute               1145     1145     1145             1145  ...
# Taboo                      596      596      596              596  ...
# Team 1                 2290388  2290388  2290388          2290388  ...
# Team 2                 2200193  2200193  2200193          2200193  ...
# World                    44184    44184    44184            44184  ...
# anime savants              204      204      204              204  ...
# x-kom Team                 366      366      366              366  ...
#
#                            wp  wp_type   att_id  att_rank   vic_id  vic_rank  \
# att_team
# --to be determined--      647      647      647       647      647       647
# ALTERNATE aTTaX           791      791      791       791      791       791
# BOOT-dS Letou             610      610      610       610      610       610
# Cerus eSports             338      338      338       338      338       338
# Chiefs                    823      823      823       823      823       823
# Dynasty                   710      710      710       710      710       710
# FlashGaming               660      660      660       660      660       660
# Grayhound                 759      759      759       759      759       759
# Ground Zero               720      720      720       720      720       720
# Guerrilla Tactics         350      350      350       350      350       350
# Legacy                    316      316      316       316      316       316
# MVP PK                   1151     1151     1151      1151     1151      1151
# PRiDE                     399      399      399       399      399       399
# SYF                       735      735      735       735      735       735
# SZ Absolute              1145     1145     1145      1145     1145      1145
# Taboo                     596      596      596       596      596       596
# Team 1                2290388  2290388  2290388   2290388  2290388   2290388
# Team 2                2200193  2200193  2200193   2200193  2200193   2200193
# World                   44184    44184    44184     44184    44184     44184
# anime savants             204      204      204       204      204       204
# x-kom Team                366      366      366       366      366       366
#
#                       att_pos_x  att_pos_y  vic_pos_x  vic_pos_y
# att_team
# --to be determined--        647        647        647        647
# ALTERNATE aTTaX             791        791        791        791
# BOOT-dS Letou               610        610        610        610
# Cerus eSports               338        338        338        338
# Chiefs                      823        823        823        823
# Dynasty                     710        710        710        710
# FlashGaming                 660        660        660        660
# Grayhound                   759        759        759        759
# Ground Zero                 720        720        720        720
# Guerrilla Tactics           350        350        350        350
# Legacy                      316        316        316        316
# MVP PK                     1151       1151       1151       1151
# PRiDE                       399        399        399        399
# SYF                         735        735        735        735
# SZ Absolute                1145       1145       1145       1145
# Taboo                       596        596        596        596
# Team 1                  2290388    2290388    2290388    2290388
# Team 2                  2200193    2200193    2200193    2200193
# World                     44184      44184      44184      44184
# anime savants               204        204        204        204
# x-kom Team                  366        366        366        366
#
# [21 rows x 22 columns]
